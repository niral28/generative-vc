# %%
import tensorflow as tf
import tensorflow_io as tfio
#import tensorflow_hub as hub
import numpy as np
import csv
import io
import librosa
import matplotlib.pyplot as plt
import IPython.display as display
from IPython.display import Audio
import scipy.io
import PIL.Image
import vggish_keras as vgk

# %%
# Modified from tutorial: https://www.tensorflow.org/tutorials/generative/style_transfer

# %%
# https://stackoverflow.com/questions/56719138/how-can-i-save-a-librosa-spectrogram-plot-as-a-specific-sized-image
def scale_minmax(X, min=0.0, max=1.0):
    X_std = (X - X.min()) / (X.max() - X.min())
    X_scaled = X_std * (max - min) + min
    return X_scaled

def preprocess(mels):
    img = scale_minmax(mels, 0, 255).astype(np.uint8)
    img = np.flip(img, axis=0) # put low frequencies at the bottom in image
    img = 255-img # invert. make black==more energy
    return img

# %%
def preprocess_spectrogram(img_arr):
    max_dim = 512
    img = img_arr
    
    # convert into 3D
    img = img.reshape((img.shape[0], img.shape[1], 1))
    img = np.tile(img, 3)
    
#     print('Image Shape', img.shape)
    img = tf.image.convert_image_dtype(img, tf.float32)
#     print('Image shape2', img.shape)
    shape = tf.cast(tf.shape(img)[:-1], tf.float32)
#     print('Shape', shape)
    long_dim = max(shape)
#     print('Longest Dim', long_dim)
    
    scale = max_dim / long_dim
    new_shape = tf.cast(shape * scale, tf.int32)
#     print('New Shape', new_shape)
    img = tf.image.resize(img, new_shape)
    img = img[tf.newaxis, :]
#     print('Final:', img.shape)
    return img

# %%
def load_img(path_to_img):
    """Preprocessing for VGG"""
    max_dim = 512
    img = tf.io.read_file(path_to_img)
    img = tf.image.decode_image(img, channels=3)
#     print(img.shape)
    img = tf.image.convert_image_dtype(img, tf.float32)
    shape = tf.cast(tf.shape(img)[:-1], tf.float32)
#     print(shape)
    long_dim = max(shape)
#     print(long_dim)
    scale = max_dim / long_dim
    new_shape = tf.cast(shape * scale, tf.int32)
    img = tf.image.resize(img, new_shape)
#     print(shape)
    img = img[tf.newaxis, :]
    return img

def imshow(image, title=None):
    if len(image.shape) > 3:
        image = tf.squeeze(image, axis=0)
        plt.imshow(image)
    if title:
        plt.title(title)

# %%
import pandas as pd
df_test_metadata = pd.read_csv('test_vox1_metadata.csv')

# %%
df_test_metadata
# Out:
#     Unnamed: 0 VoxCeleb1 ID        VGGFace1 ID Gender Nationality   Set  \
# 0          269      id10270        Eartha_Kitt      f         USA  test
# 1          270      id10271        Ed_Westwick      m          UK  test
# 2          271      id10272      Eddie_Griffin      m         USA  test
# 3          272      id10273       Eddie_Izzard      m          UK  test
# 4          273      id10274  Eddie_Kaye_Thomas      m         USA  test
# 5          274      id10275   Eddie_McClintock      m         USA  test
# 6          275      id10276       Edgar_Wright      m          UK  test
# 7          276      id10277    Eduardo_Noriega      m       Spain  test
# 8          277      id10278       Edward_Asner      m         USA  test
# 9          278      id10279      Efren_Ramirez      m         USA  test
# 10         279      id10280     Elaine_Cassidy      f     Ireland  test
# 11         280      id10281     Elaine_Hendrix      f         USA  test
# 12         281      id10282  Eleanor_Tomlinson      f          UK  test
# 13         282      id10283           Eli_Roth      m         USA  test
# 14         283      id10284        Eli_Wallach      m         USA  test
# 15         284      id10285     Elisabeth_Moss      f         USA  test
# 16         285      id10286       Elle_Fanning      f         USA  test
# 17         286      id10287      Ellen_Burstyn      f         USA  test
# 18         287      id10288         Ellen_Wong      f      Canada  test
# 19         288      id10289        Elodie_Yung      f      France  test
# 20         289      id10290       Emile_Hirsch      m         USA  test
# 21         290      id10291        Emily_Atack      f          UK  test
# 22         291      id10292      Emraan_Hashmi      m       India  test
# 23         292      id10293        Eoin_Macken      m     Ireland  test
# 24         293      id10294       Eric_Braeden      m         USA  test
# 25         294      id10295          Eric_Dane      m         USA  test
# 26         295      id10296     Eric_McCormack      m         USA  test
# 27         296      id10297       Eric_Roberts      m         USA  test
# 28         297      id10298       Erik_Estrada      m         USA  test
# 29         298      id10299       Erin_Andrews      f         USA  test
# 30         299      id10300    Ernest_Borgnine      m         USA  test
# 31         300      id10301       Ernie_Hudson      m         USA  test
# 32         301      id10302       Esai_Morales      m         USA  test
# 33         302      id10303     Estelle_Harris      f         USA  test
# 34         303      id10304        Eugene_Levy      m      Canada  test
# 35         304      id10305     Eugenio_Derbez      m      Mexico  test
# 36         305      id10306          Eva_Green      f      Norway  test
# 37         306      id10307       Eva_Longoria      f         USA  test
# 38         307      id10308       Evanna_Lynch      f     Ireland  test
# 39         308      id10309        Ezra_Miller      m         USA  test
#
#                                          full_paths
# 0   ./data/spmel_test/id10270/x6uYqmx31kE_00002.npy
# 1   ./data/spmel_test/id10271/zWyD72sHVwA_00001.npy
# 2   ./data/spmel_test/id10272/wb6ligRbbZ4_00001.npy
# 3   ./data/spmel_test/id10273/xN2fSTQHHkw_00002.npy
# 4   ./data/spmel_test/id10274/xbGp2KSUr0E_00001.npy
# 5   ./data/spmel_test/id10275/mWZ3l5OoyVI_00002.npy
# 6   ./data/spmel_test/id10276/3vWez3baO60_00002.npy
# 7   ./data/spmel_test/id10277/cELY3LdIo-0_00003.npy
# 8   ./data/spmel_test/id10278/y990f6UiEEM_00001.npy
# 9   ./data/spmel_test/id10279/4Q1IvdayPR8_00014.npy
# 10  ./data/spmel_test/id10280/9AtE4C309P8_00017.npy
# 11  ./data/spmel_test/id10281/1CiBWgsHT4E_00009.npy
# 12  ./data/spmel_test/id10282/qkZNuvX1UNo_00006.npy
# 13  ./data/spmel_test/id10283/p3q7Z0O6rgg_00003.npy
# 14  ./data/spmel_test/id10284/7yx9A0yzLYk_00031.npy
# 15  ./data/spmel_test/id10285/thghCiJZYwI_00002.npy
# 16  ./data/spmel_test/id10286/lBkbWztMEUY_00004.npy
# 17  ./data/spmel_test/id10287/I99R40TUF1s_00005.npy
# 18  ./data/spmel_test/id10288/A3ZvNuG8_oM_00001.npy
# 19  ./data/spmel_test/id10289/zFii0ROZZjc_00006.npy
# 20  ./data/spmel_test/id10290/dDnqp9503Mg_00005.npy
# 21  ./data/spmel_test/id10291/d2Lasybvo7s_00001.npy
# 22  ./data/spmel_test/id10292/ya6VNZp-pXw_00023.npy
# 23  ./data/spmel_test/id10293/nAtqrkWKIhM_00006.npy
# 24  ./data/spmel_test/id10294/NRMQOFYS41I_00002.npy
# 25  ./data/spmel_test/id10295/S9FeIMntmUE_00001.npy
# 26  ./data/spmel_test/id10296/_BVSKK5mGnY_00001.npy
# 27  ./data/spmel_test/id10297/0mtJFC7OJv4_00004.npy
# 28  ./data/spmel_test/id10298/qrJ0fQJP5gs_00001.npy
# 29  ./data/spmel_test/id10299/uaPd2Ix-wSI_00011.npy
# 30  ./data/spmel_test/id10300/SQzWyPhRqmk_00002.npy
# 31  ./data/spmel_test/id10301/vhzF7dhGJzI_00006.npy
# 32  ./data/spmel_test/id10302/ekqJava7sdE_00007.npy
# 33  ./data/spmel_test/id10303/LKDWhdJQFco_00019.npy
# 34  ./data/spmel_test/id10304/7geDDtDmWQU_00006.npy
# 35  ./data/spmel_test/id10305/Piw0wvQbpnQ_00008.npy
# 36  ./data/spmel_test/id10306/cc5WSHcgkl8_00003.npy
# 37  ./data/spmel_test/id10307/wtqPC9vEZ0M_00002.npy
# 38  ./data/spmel_test/id10308/MxBuaaxNnlE_00006.npy
# 39  ./data/spmel_test/id10309/RkN41E3gRpc_00005.npy

# %%
import pandas as pd
df_test_metadata = pd.read_csv('test_vox1_metadata.csv')
images = {}
for row in df_test_metadata.iterrows():
    row_item = row[1]
    user_id = row_item['VoxCeleb1 ID']
    images[user_id] = row_item['full_paths'].replace('spmel_test','wavtest').replace('_0','/0')[:-4]+'.wav'
#     fig, ax = plt.subplots(2,1)
#     fig.suptitle(f'Image:{user_id}')
#     ax[0].imshow(np.load(row_item['full_paths']).T)
#     ax[0].set_title('Original')
    
#     ax[1].imshow(images[user_id][0])
#     ax[1].set_title('Preprocessed')

# %%
import itertools
image_combinations = list(map(dict, itertools.combinations(
    images.items(), 2)))

# %%
image_combinations
# Out:
# [{'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10271': './data/wavtest/id10271/zWyD72sHVwA/00001.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10281': './data/wavtest/id10281/1CiBWgsHT4E/00009.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10282': './data/wavtest/id10282/qkZNuvX1UNo/00006.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10283': './data/wavtest/id10283/p3q7Z0O6rgg/00003.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10284': './data/wavtest/id10284/7yx9A0yzLYk/00031.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10285': './data/wavtest/id10285/thghCiJZYwI/00002.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10286': './data/wavtest/id10286/lBkbWztMEUY/00004.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10287': './data/wavtest/id10287/I99R40TUF1s/00005.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10288': './data/wavtest/id10288/A3ZvNuG8_oM/00001.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10289': './data/wavtest/id10289/zFii0ROZZjc/00006.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10290': './data/wavtest/id10290/dDnqp9503Mg/00005.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10291': './data/wavtest/id10291/d2Lasybvo7s/00001.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10292': './data/wavtest/id10292/ya6VNZp-pXw/00023.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10293': './data/wavtest/id10293/nAtqrkWKIhM/00006.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10294': './data/wavtest/id10294/NRMQOFYS41I/00002.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10295': './data/wavtest/id10295/S9FeIMntmUE/00001.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10296': './data/wavtest/id10296/_BVSKK5mGnY/00001.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10297': './data/wavtest/id10297/0mtJFC7OJv4/00004.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id10298': './data/wavtest/id10298/qrJ0fQJP5gs/00001.wav'},
#  {'id10270': './data/wavtest/id10270/x6uYqmx31kE/00002.wav',
#   'id
id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10283': './data/wavtest/id10283/p3q7Z0O6rgg/00003.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10284': './data/wavtest/id10284/7yx9A0yzLYk/00031.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10285': './data/wavtest/id10285/thghCiJZYwI/00002.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10286': './data/wavtest/id10286/lBkbWztMEUY/00004.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10287': './data/wavtest/id10287/I99R40TUF1s/00005.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10288': './data/wavtest/id10288/A3ZvNuG8_oM/00001.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10289': './data/wavtest/id10289/zFii0ROZZjc/00006.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10290': './data/wavtest/id10290/dDnqp9503Mg/00005.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10291': './data/wavtest/id10291/d2Lasybvo7s/00001.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10292': './data/wavtest/id10292/ya6VNZp-pXw/00023.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10293': './data/wavtest/id10293/nAtqrkWKIhM/00006.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10294': './data/wavtest/id10294/NRMQOFYS41I/00002.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10295': './data/wavtest/id10295/S9FeIMntmUE/00001.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10296': './data/wavtest/id10296/_BVSKK5mGnY/00001.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10297': './data/wavtest/id10297/0mtJFC7OJv4/00004.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10298': './data/wavtest/id10298/qrJ0fQJP5gs/00001.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10299': './data/wavtest/id10299/uaPd2Ix-wSI/00011.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10300': './data/wavtest/id10300/SQzWyPhRqmk/00002.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10272': './data/wavtest/id10272/wb6ligRbbZ4/00001.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10281': './data/wavtest/id10281/1CiBWgsHT4E/00009.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10282': './data/wavtest/id10282/qkZNuvX1UNo/00006.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10283': './data/wavtest/id10283/p3q7Z0O6rgg/00003.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10284': './data/wavtest/id10284/7yx9A0yzLYk/00031.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10285': './data/wavtest/id10285/thghCiJZYwI/00002.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10286': './data/wavtest/id10286/lBkbWztMEUY/00004.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10287': './data/wavtest/id10287/I99R40TUF1s/00005.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10288': './data/wavtest/id10288/A3ZvNuG8_oM/00001.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10289': './data/wavtest/id10289/zFii0ROZZjc/00006.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10290': './data/wavtest/id10290/dDnqp9503Mg/00005.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10291': './data/wavtest/id10291/d2Lasybvo7s/00001.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10292': './data/wavtest/id10292/ya6VNZp-pXw/00023.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10293': './data/wavtest/id10293/nAtqrkWKIhM/00006.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10294': './data/wavtest/id10294/NRMQOFYS41I/00002.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10295': './data/wavtest/id10295/S9FeIMntmUE/00001.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10296': './data/wavtest/id10296/_BVSKK5mGnY/00001.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10297': './data/wavtest/id10297/0mtJFC7OJv4/00004.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10298': './data/wavtest/id10298/qrJ0fQJP5gs/00001.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10299': './data/wavtest/id10299/uaPd2Ix-wSI/00011.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10300': './data/wavtest/id10300/SQzWyPhRqmk/00002.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10273': './data/wavtest/id10273/xN2fSTQHHkw/00002.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10281': './data/wavtest/id10281/1CiBWgsHT4E/00009.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10282': './data/wavtest/id10282/qkZNuvX1UNo/00006.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10283': './data/wavtest/id10283/p3q7Z0O6rgg/00003.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10284': './data/wavtest/id10284/7yx9A0yzLYk/00031.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10285': './data/wavtest/id10285/thghCiJZYwI/00002.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10286': './data/wavtest/id10286/lBkbWztMEUY/00004.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10287': './data/wavtest/id10287/I99R40TUF1s/00005.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10288': './data/wavtest/id10288/A3ZvNuG8_oM/00001.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10289': './data/wavtest/id10289/zFii0ROZZjc/00006.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10290': './data/wavtest/id10290/dDnqp9503Mg/00005.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10291': './data/wavtest/id10291/d2Lasybvo7s/00001.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10292': './data/wavtest/id10292/ya6VNZp-pXw/00023.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10293': './data/wavtest/id10293/nAtqrkWKIhM/00006.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10294': './data/wavtest/id10294/NRMQOFYS41I/00002.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10295': './data/wavtest/id10295/S9FeIMntmUE/00001.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10296': './data/wavtest/id10296/_BVSKK5mGnY/00001.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10297': './data/wavtest/id10297/0mtJFC7OJv4/00004.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10298': './data/wavtest/id10298/qrJ0fQJP5gs/00001.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10299': './data/wavtest/id10299/uaPd2Ix-wSI/00011.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10300': './data/wavtest/id10300/SQzWyPhRqmk/00002.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10274': './data/wavtest/id10274/xbGp2KSUr0E/00001.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10281': './data/wavtest/id10281/1CiBWgsHT4E/00009.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10282': './data/wavtest/id10282/qkZNuvX1UNo/00006.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10283': './data/wavtest/id10283/p3q7Z0O6rgg/00003.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10284': './data/wavtest/id10284/7yx9A0yzLYk/00031.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10285': './data/wavtest/id10285/thghCiJZYwI/00002.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10286': './data/wavtest/id10286/lBkbWztMEUY/00004.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10287': './data/wavtest/id10287/I99R40TUF1s/00005.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10288': './data/wavtest/id10288/A3ZvNuG8_oM/00001.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10289': './data/wavtest/id10289/zFii0ROZZjc/00006.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10290': './data/wavtest/id10290/dDnqp9503Mg/00005.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10291': './data/wavtest/id10291/d2Lasybvo7s/00001.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10292': './data/wavtest/id10292/ya6VNZp-pXw/00023.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10293': './data/wavtest/id10293/nAtqrkWKIhM/00006.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10294': './data/wavtest/id10294/NRMQOFYS41I/00002.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10295': './data/wavtest/id10295/S9FeIMntmUE/00001.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10296': './data/wavtest/id10296/_BVSKK5mGnY/00001.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10297': './data/wavtest/id10297/0mtJFC7OJv4/00004.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10298': './data/wavtest/id10298/qrJ0fQJP5gs/00001.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10299': './data/wavtest/id10299/uaPd2Ix-wSI/00011.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10300': './data/wavtest/id10300/SQzWyPhRqmk/00002.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10275': './data/wavtest/id10275/mWZ3l5OoyVI/00002.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10281': './data/wavtest/id10281/1CiBWgsHT4E/00009.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10282': './data/wavtest/id10282/qkZNuvX1UNo/00006.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10283': './data/wavtest/id10283/p3q7Z0O6rgg/00003.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10284': './data/wavtest/id10284/7yx9A0yzLYk/00031.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10285': './data/wavtest/id10285/thghCiJZYwI/00002.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10286': './data/wavtest/id10286/lBkbWztMEUY/00004.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10287': './data/wavtest/id10287/I99R40TUF1s/00005.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10288': './data/wavtest/id10288/A3ZvNuG8_oM/00001.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10289': './data/wavtest/id10289/zFii0ROZZjc/00006.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10290': './data/wavtest/id10290/dDnqp9503Mg/00005.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10291': './data/wavtest/id10291/d2Lasybvo7s/00001.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10292': './data/wavtest/id10292/ya6VNZp-pXw/00023.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10293': './data/wavtest/id10293/nAtqrkWKIhM/00006.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10294': './data/wavtest/id10294/NRMQOFYS41I/00002.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10295': './data/wavtest/id10295/S9FeIMntmUE/00001.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10296': './data/wavtest/id10296/_BVSKK5mGnY/00001.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10297': './data/wavtest/id10297/0mtJFC7OJv4/00004.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10298': './data/wavtest/id10298/qrJ0fQJP5gs/00001.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10299': './data/wavtest/id10299/uaPd2Ix-wSI/00011.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10300': './data/wavtest/id10300/SQzWyPhRqmk/00002.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10276': './data/wavtest/id10276/3vWez3baO60/00002.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10281': './data/wavtest/id10281/1CiBWgsHT4E/00009.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10282': './data/wavtest/id10282/qkZNuvX1UNo/00006.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10283': './data/wavtest/id10283/p3q7Z0O6rgg/00003.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10284': './data/wavtest/id10284/7yx9A0yzLYk/00031.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10285': './data/wavtest/id10285/thghCiJZYwI/00002.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10286': './data/wavtest/id10286/lBkbWztMEUY/00004.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10287': './data/wavtest/id10287/I99R40TUF1s/00005.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10288': './data/wavtest/id10288/A3ZvNuG8_oM/00001.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10289': './data/wavtest/id10289/zFii0ROZZjc/00006.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10290': './data/wavtest/id10290/dDnqp9503Mg/00005.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10291': './data/wavtest/id10291/d2Lasybvo7s/00001.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10292': './data/wavtest/id10292/ya6VNZp-pXw/00023.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10293': './data/wavtest/id10293/nAtqrkWKIhM/00006.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10294': './data/wavtest/id10294/NRMQOFYS41I/00002.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10295': './data/wavtest/id10295/S9FeIMntmUE/00001.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10296': './data/wavtest/id10296/_BVSKK5mGnY/00001.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10297': './data/wavtest/id10297/0mtJFC7OJv4/00004.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10298': './data/wavtest/id10298/qrJ0fQJP5gs/00001.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10299': './data/wavtest/id10299/uaPd2Ix-wSI/00011.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10300': './data/wavtest/id10300/SQzWyPhRqmk/00002.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10277': './data/wavtest/id10277/cELY3LdIo-0/00003.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10281': './data/wavtest/id10281/1CiBWgsHT4E/00009.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10282': './data/wavtest/id10282/qkZNuvX1UNo/00006.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10283': './data/wavtest/id10283/p3q7Z0O6rgg/00003.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10284': './data/wavtest/id10284/7yx9A0yzLYk/00031.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10285': './data/wavtest/id10285/thghCiJZYwI/00002.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10286': './data/wavtest/id10286/lBkbWztMEUY/00004.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10287': './data/wavtest/id10287/I99R40TUF1s/00005.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10288': './data/wavtest/id10288/A3ZvNuG8_oM/00001.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10289': './data/wavtest/id10289/zFii0ROZZjc/00006.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10290': './data/wavtest/id10290/dDnqp9503Mg/00005.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10291': './data/wavtest/id10291/d2Lasybvo7s/00001.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10292': './data/wavtest/id10292/ya6VNZp-pXw/00023.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10293': './data/wavtest/id10293/nAtqrkWKIhM/00006.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10294': './data/wavtest/id10294/NRMQOFYS41I/00002.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10295': './data/wavtest/id10295/S9FeIMntmUE/00001.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10296': './data/wavtest/id10296/_BVSKK5mGnY/00001.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10297': './data/wavtest/id10297/0mtJFC7OJv4/00004.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10298': './data/wavtest/id10298/qrJ0fQJP5gs/00001.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10299': './data/wavtest/id10299/uaPd2Ix-wSI/00011.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10300': './data/wavtest/id10300/SQzWyPhRqmk/00002.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10278': './data/wavtest/id10278/y990f6UiEEM/00001.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10281': './data/wavtest/id10281/1CiBWgsHT4E/00009.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10282': './data/wavtest/id10282/qkZNuvX1UNo/00006.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10283': './data/wavtest/id10283/p3q7Z0O6rgg/00003.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10284': './data/wavtest/id10284/7yx9A0yzLYk/00031.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10285': './data/wavtest/id10285/thghCiJZYwI/00002.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10286': './data/wavtest/id10286/lBkbWztMEUY/00004.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10287': './data/wavtest/id10287/I99R40TUF1s/00005.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10288': './data/wavtest/id10288/A3ZvNuG8_oM/00001.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10289': './data/wavtest/id10289/zFii0ROZZjc/00006.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10290': './data/wavtest/id10290/dDnqp9503Mg/00005.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10291': './data/wavtest/id10291/d2Lasybvo7s/00001.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10292': './data/wavtest/id10292/ya6VNZp-pXw/00023.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10293': './data/wavtest/id10293/nAtqrkWKIhM/00006.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10294': './data/wavtest/id10294/NRMQOFYS41I/00002.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10295': './data/wavtest/id10295/S9FeIMntmUE/00001.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10296': './data/wavtest/id10296/_BVSKK5mGnY/00001.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10297': './data/wavtest/id10297/0mtJFC7OJv4/00004.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10298': './data/wavtest/id10298/qrJ0fQJP5gs/00001.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10299': './data/wavtest/id10299/uaPd2Ix-wSI/00011.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10300': './data/wavtest/id10300/SQzWyPhRqmk/00002.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10279': './data/wavtest/id10279/4Q1IvdayPR8/00014.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10281': './data/wavtest/id10281/1CiBWgsHT4E/00009.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10282': './data/wavtest/id10282/qkZNuvX1UNo/00006.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10283': './data/wavtest/id10283/p3q7Z0O6rgg/00003.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10284': './data/wavtest/id10284/7yx9A0yzLYk/00031.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10285': './data/wavtest/id10285/thghCiJZYwI/00002.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10286': './data/wavtest/id10286/lBkbWztMEUY/00004.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10287': './data/wavtest/id10287/I99R40TUF1s/00005.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10288': './data/wavtest/id10288/A3ZvNuG8_oM/00001.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10289': './data/wavtest/id10289/zFii0ROZZjc/00006.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10290': './data/wavtest/id10290/dDnqp9503Mg/00005.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10291': './data/wavtest/id10291/d2Lasybvo7s/00001.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10292': './data/wavtest/id10292/ya6VNZp-pXw/00023.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10293': './data/wavtest/id10293/nAtqrkWKIhM/00006.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10294': './data/wavtest/id10294/NRMQOFYS41I/00002.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10295': './data/wavtest/id10295/S9FeIMntmUE/00001.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.wav',
#   'id10296': './data/wavtest/id10296/_BVSKK5mGnY/00001.wav'},
#  {'id10280': './data/wavtest/id10280/9AtE4C309P8/00017.w
#  {'id10300': './data/wavtest/id10300/SQzWyPhRqmk/00002.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav',
#   'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav'},
#  {'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav',
#   'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav'},
#  {'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav',
#   'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav'},
#  {'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav',
#   'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav'},
#  {'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav',
#   'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav'},
#  {'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav',
#   'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav'},
#  {'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10301': './data/wavtest/id10301/vhzF7dhGJzI/00006.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav',
#   'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav'},
#  {'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav',
#   'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav'},
#  {'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav',
#   'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav'},
#  {'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav',
#   'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav'},
#  {'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav',
#   'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav'},
#  {'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10302': './data/wavtest/id10302/ekqJava7sdE/00007.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav',
#   'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav'},
#  {'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav',
#   'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav'},
#  {'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav',
#   'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav'},
#  {'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav',
#   'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav'},
#  {'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10303': './data/wavtest/id10303/LKDWhdJQFco/00019.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav',
#   'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav'},
#  {'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav',
#   'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav'},
#  {'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav',
#   'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav'},
#  {'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10304': './data/wavtest/id10304/7geDDtDmWQU/00006.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav',
#   'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav'},
#  {'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav',
#   'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav'},
#  {'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10305': './data/wavtest/id10305/Piw0wvQbpnQ/00008.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav',
#   'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav'},
#  {'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10306': './data/wavtest/id10306/cc5WSHcgkl8/00003.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav',
#   'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav'},
#  {'id10307': './data/wavtest/id10307/wtqPC9vEZ0M/00002.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'},
#  {'id10308': './data/wavtest/id10308/MxBuaaxNnlE/00006.wav',
#   'id10309': './data/wavtest/id10309/RkN41E3gRpc/00005.wav'}]

# %%
content_layers = ['conv4/conv4_2'] 

style_layers = ['conv1',
                'conv2',
                'conv3/conv3_1', 
                'conv3/conv3_2', 
                'conv4/conv4_1']

# %%
num_content_layers = len(content_layers)
num_style_layers = len(style_layers)

# %%
def vgg_layers(layer_names):
    """ Creates a vgg model that returns a list of intermediate output values."""
    # Load our model. Load pretrained VGG, trained on imagenet data
    vgg = vgk.VGGish(include_top=False, weights='audioset')
    #get activations from layers we're interested in
    outputs = [vgg.get_layer(name).output for name in layer_names]
    model = tf.keras.Model([vgg.input], outputs)
    return model

# %%
def gram_matrix(input_tensor):
    result = tf.linalg.einsum('bijc,bijd->bcd', input_tensor, input_tensor)
    input_shape = tf.shape(input_tensor)
    num_locations = tf.cast(input_shape[1]*input_shape[2], tf.float32)
    return result/(num_locations)

# %%
class StyleContentModel(tf.keras.models.Model):
    def __init__(self, style_layers, content_layers):
        super(StyleContentModel, self).__init__()
        self.vgg = vgg_layers(style_layers+content_layers)
        self.style_layers = style_layers
        self.content_layers = content_layers
        self.num_style_layers = len(style_layers)
        self.vgg.trainable = False 
        
    def call(self, inputs):
        """Expects float input in [0,1]"""
        outputs = self.vgg(inputs)
        style_outputs, content_outputs = (outputs[:self.num_style_layers], 
                                      outputs[self.num_style_layers:])
        style_outputs = [gram_matrix(style_output) for style_output in style_outputs]
        content_dict = {content_name:value for content_name,value in zip(self.content_layers, content_outputs)}
        style_dict = {
            style_name:value 
            for style_name, value
            in zip(self.style_layers, style_outputs)
        }
        return {'content': content_dict, 'style': style_dict}

# %%
def tensor_to_image(tensor):
    tensor = tensor*255
    tensor = np.array(tensor, dtype=np.uint8)
    if np.ndim(tensor)>3:
        assert tensor.shape[0] == 1
        tensor = tensor[0]
    return PIL.Image.fromarray(tensor)

# %%
def tensor_to_audio(tensor):
    tensor = tensor*255
    tensor = np.array(tensor, dtype=np.uint8)
    if np.ndim(tensor)>3:
        assert tensor.shape[0] == 1
        tensor = tensor[0]
    tensor = tf.reduce_mean(tensor,axis=-1)
    audio_arr = librosa.feature.inverse.mel_to_audio(tensor.numpy().astype(np.float64), sr=16000, n_fft=1024, hop_length=256, n_iter=64)
    return audio_arr

# %%
def get_audio_data(pair):

    def clip_0_1(image):
        return tf.clip_by_value(image, clip_value_min=0.0, clip_value_max=1.0)

    def style_content_loss(outputs):
        style_outputs = outputs['style']
        print(style_outputs)
        content_outputs = outputs['content']
        print(content_outputs)
        style_loss = 0 
        
        for name in style_outputs.keys():
            print(tf.reduce_mean((style_outputs[name]-style_targets[name])**2))
                  
        style_loss = tf.add_n([tf.reduce_mean((style_outputs[name]-style_targets[name])**2) for name in style_outputs.keys()])
        
        
        print('Style Loss', style_loss)
        content_loss = tf.add_n([tf.reduce_mean((content_outputs[name]-content_targets[name])**2) 
                                 for name in content_outputs.keys()])
        print('Content Loss', content_loss)
        content_loss *= content_weight / num_content_layers
        loss = style_loss + content_loss
        return loss

    @tf.function()
    def train_step(image):
        with tf.GradientTape() as tape:
            outputs = extractor(image)
            loss = style_content_loss(outputs)
        grad = tape.gradient(loss, image)
        opt.apply_gradients([(grad, image)])
        image.assign(clip_0_1(image))
    
    
    
    opt = tf.optimizers.Adam(learning_rate=0.02, beta_1=0.99, epsilon=1e-1)
    image = None
    style_weight=1e-2
    content_weight=1e4
    
    content_image_id, style_image_id = pair.keys()
    content_image = vgk.get_features(pair[content_image_id])
    style_image =  vgk.get_features(pair[style_image_id])
    extractor = StyleContentModel(style_layers, content_layers)
    style_targets = extractor(style_image)['style']
    content_targets = extractor(content_image)['content']
    
    if image is None:
        image = tf.Variable(content_image)
    else:
        image.assign(content_image)
    audio_arr = None
    spec_img = None
    for n in range(epochs):
        for m in range(steps_per_epoch):
            train_step(image)
            print(".", end='')
        
        spec_img = image[:,:,0]
        audio_arr = tensor_to_audio(image)
        print("Train step: {}".format(m))
    filename = f'{content_image_id}x{style_image_id}_vggish'
    print(filename)
    if audio_arr is not None:
        scipy.io.wavfile.write(filename+'.wav', 16000, audio_arr)
        plt.imsave(filename+'.png', np.array(spec_img)[0])

# %%
extractor = StyleContentModel(style_layers, content_layers)

# %%
epochs = 1 # 10
steps_per_epoch = 10 #100

for pair in image_combinations:
    print(pair.values())
    get_audio_data(pair)
#     content_image_id, style_image_id = pair.keys()
#     content_image = vgk.get_features(pair[content_image_id])
#     print(content_image.shape)
    
#     style_image =  vgk.get_features(pair[style_image_id])
#     print(style_image.shape)
    
#     style_targets = extractor(style_image)['style']
#     print(style_targets.keys())
#     content_targets = extractor(content_image)['content']
#     print(content_targets.keys())
# Out:
# dict_values(['./data/wavtest/id10270/x6uYqmx31kE/00002.wav', './data/wavtest/id10271/zWyD72sHVwA/00001.wav'])
# (1, 96, 64, 1)
# (3, 96, 64, 1)
# {'conv1': <tf.Tensor 'style_content_model_32/truediv:0' shape=(1, 64, 64) dtype=float32>, 'conv2': <tf.Tensor 'style_content_model_32/truediv_1:0' shape=(1, 128, 128) dtype=float32>, 'conv3/conv3_1': <tf.Tensor 'style_content_model_32/truediv_2:0' shape=(1, 256, 256) dtype=float32>, 'conv3/conv3_2': <tf.Tensor 'style_content_model_32/truediv_3:0' shape=(1, 256, 256) dtype=float32>, 'conv4/conv4_1': <tf.Tensor 'style_content_model_32/truediv_4:0' shape=(1, 512, 512) dtype=float32>}
# {'conv4/conv4_2': <tf.Tensor 'style_content_model_32/functional_65/conv4/conv4_2/Relu:0' shape=(1, 12, 8, 512) dtype=float32>}
# Tensor("Mean:0", shape=(), dtype=float32)
# Tensor("Mean_1:0", shape=(), dtype=float32)
# Tensor("Mean_2:0", shape=(), dtype=float32)
# Tensor("Mean_3:0", shape=(), dtype=float32)
# Tensor("Mean_4:0", shape=(), dtype=float32)
# Style Loss Tensor("AddN:0", shape=(), dtype=float32)
# Content Loss Tensor("Mean_10:0", shape=(), dtype=float32)
# {'conv1': <tf.Tensor 'style_content_model_32/truediv:0' shape=(1, 64, 64) dtype=float32>, 'conv2': <tf.Tensor 'style_content_model_32/truediv_1:0' shape=(1, 128, 128) dtype=float32>, 'conv3/conv3_1': <tf.Tensor 'style_content_model_32/truediv_2:0' shape=(1, 256, 256) dtype=float32>, 'conv3/conv3_2': <tf.Tensor 'style_content_model_32/truediv_3:0' shape=(1, 256, 256) dtype=float32>, 'conv4/conv4_1': <tf.Tensor 'style_content_model_32/truediv_4:0' shape=(1, 512, 512) dtype=float32>}
# {'conv4/conv4_2': <tf.Tensor 'style_content_model_32/functional_65/conv4/conv4_2/Relu:0' shape=(1, 12, 8, 512) dtype=float32>}
# Tensor("Mean:0", shape=(), dtype=float32)
# Tensor("Mean_1:0", shape=(), dtype=float32)
# Tensor("Mean_2:0", shape=(), dtype=float32)
# Tensor("Mean_3:0", shape=(), dtype=float32)
# Tensor("Mean_4:0", shape=(), dtype=float32)
# Style Loss Tensor("AddN:0", shape=(), dtype=float32)
# Content Loss Tensor("Mean_10:0", shape=(), dtype=float32)
# ..........Train step: 9
# id10270xid10271_vggish
# dict_values(['./data/wavtest/id10270/x6uYqmx31kE/00002.wav', './data/wavtest/id10272/wb6ligRbbZ4/00001.wav'])
# (1, 96, 64, 1)
# (1, 96, 64, 1)
# {'conv1': <tf.Tensor 'style_content_model_33/truediv:0' shape=(1, 64, 64) dtype=float32>, 'conv2': <tf.Tensor 'style_content_model_33/truediv_1:0' shape=(1, 128, 128) dtype=float32>, 'conv3/conv3_1': <tf.Tensor 'style_content_model_33/truediv_2:0' shape=(1, 256, 256) dtype=float32>, 'conv3/conv3_2': <tf.Tensor 'style_content_model_33/truediv_3:0' shape=(1, 256, 256) dtype=float32>, 'conv4/conv4_1': <tf.Tensor 'style_content_model_33/truediv_4:0' shape=(1, 512, 512) dtype=float32>}
# {'conv4/conv4_2': <tf.Tensor 'style_content_model_33/functional_67/conv4/conv4_2/Relu:0' shape=(1, 12, 8, 512) dtype=float32>}
# Tensor("Mean:0", shape=(), dtype=float32)
# Tensor("Mean_1:0", shape=(), dtype=float32)
# Tensor("Mean_2:0", shape=(), dtype=float32)
# Tensor("Mean_3:0", shape=(), dtype=float32)
# Tensor("Mean_4:0", shape=(), dtype=float32)
# Style Loss Tensor("AddN:0", shape=(), dtype=float32)
# Content Loss Tensor("Mean_10:0", shape=(), dtype=float32)
# {'conv1': <tf.Tensor 'style_content_model_33/truediv:0' shape=(1, 64, 64) dtype=float32>, 'conv2': <tf.Tensor 'style_content_model_33/truediv_1:0' shape=(1, 128, 128) dtype=float32>, 'conv3/conv3_1': <tf.Tensor 'style_content_model_33/truediv_2:0' shape=(1, 256, 256) dtype=float32>, 'conv3/conv3_2': <tf.Tensor 'style_content_model_33/truediv_3:0' shape=(1, 256, 256) dtype=float32>, 'conv4/conv4_1': <tf.Tensor 'style_content_model_33/truediv_4:0' shape=(1, 512, 512) dtype=float32>}
# {'conv4/conv4_2': <tf.Tensor 'style_content_model_33/functional_67/conv4/conv4_2/Relu:0' shape=(1, 12, 8, 512) dtype=float32>}
# Tensor("Mean:0", shape=(), dtype=float32)
# Tensor("Mean_1:0", shape=(), dtype=float32)
# Tensor("Mean_2:0", shape=(), dtype=float32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-874a1ce183c9> in <module>()
#       4 for pair in image_combinations:
#       5     print(pair.values())
# ----> 6     get_audio_data(pair)
#       7 #     content_image_id, style_image_id = pair.keys()
#       8 #     content_image = vgk.get_features(pair[content_image_id])
#
# <ipython-input-63-cdee331df448> in get_audio_data(pair)
#      57     for n in range(epochs):
#      58         for m in range(steps_per_epoch):
# ---> 59             train_step(image)
#      60             print(".", end='')
#      61
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     838         # Lifting succeeded, so variables are initialized and we can run the
#     839         # stateless function.
# --> 840         return self._stateless_fn(*args, **kwds)
#     841     else:
#     842       canon_args, canon_kwds = \
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2826     """Calls a graph function specialized to the inputs."""
#    2827     with self._lock:
# -> 2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#    2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#    3215       return graph_function, args, kwargs
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3073             arg_names=arg_names,
#    3074             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3075             capture_by_value=self._capture_by_value),
#    3076         self._function_attributes,
#    3077         function_spec=self.function_spec,
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     598         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     599         # the function a weak reference to itself to avoid a reference cycle.
# --> 600         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     601     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     602
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     967                     recursive=True,
#     968                     optional_features=autograph_options,
# --> 969                     user_requested=True,
#     970                 ))
#     971           except Exception as e:  # pylint:disable=broad-except
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     594     try:
#     595       if kwargs is not None:
# --> 596         result = converted_f(*effective_args, **kwargs)
#     597       else:
#     598         result = converted_f(*effective_args)
#
# /var/folders/1y/kzwftcsj0sdf0y2rw1jkcjzm0000gn/T/tmpvx068oqs.py in tf__train_step(image)
#      12                 with ag__.ld(tf).GradientTape() as tape:
#      13                     outputs = ag__.converted_call(ag__.ld(extractor), (ag__.ld(image),), None, fscope)
# ---> 14                     loss = ag__.converted_call(ag__.ld(style_content_loss), (ag__.ld(outputs),), None, fscope)
#      15                 grad = ag__.converted_call(ag__.ld(tape).gradient, (ag__.ld(loss), ag__.ld(image)), None, fscope)
#      16                 ag__.converted_call(ag__.ld(opt).apply_gradients, ([(ag__.ld(grad), ag__.ld(image))],), None, fscope)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     596         result = converted_f(*effective_args, **kwargs)
#     597       else:
# --> 598         result = converted_f(*effective_args)
#     599     except Exception as e:
#     600       _attach_metadata(e, converted_f)
#
# /var/folders/1y/kzwftcsj0sdf0y2rw1jkcjzm0000gn/T/tmpagq4xw7e.py in tf__style_content_loss(outputs)
#      27                     ag__.ld(print)(ag__.converted_call(ag__.ld(tf).reduce_mean, (((ag__.ld(style_outputs)[ag__.ld(name)] - ag__.ld(style_targets)[ag__.ld(name)]) ** 2),), None, fscope))
#      28                 name = ag__.Undefined('name')
# ---> 29                 ag__.for_stmt(ag__.converted_call(ag__.ld(style_outputs).keys, (), None, fscope), None, loop_body, get_state, set_state, (), {'iterate_names': 'name'})
#      30                 style_loss = ag__.converted_call(ag__.ld(tf).add_n, ([ag__.converted_call(ag__.ld(tf).reduce_mean, (((ag__.ld(style_outputs)[ag__.ld(name)] - ag__.ld(style_targets)[ag__.ld(name)]) ** 2),), None, fscope) for name in ag__.converted_call(ag__.ld(style_outputs).keys, (), None, fscope)],), None, fscope)
#      31                 ag__.ld(print)('Style Loss', ag__.ld(style_loss))
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/autograph/operators/control_flow.py in for_stmt(iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#     366
#     367   else:
# --> 368     _py_for_stmt(iter_, extra_test, body, None, None)
#     369
#     370
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_for_stmt(***failed resolving arguments***)
#     395   else:
#     396     for target in iter_:
# --> 397       body(target)
#     398
#     399
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/autograph/operators/control_flow.py in protected_body(protected_iter)
#     381     original_body = body
#     382     def protected_body(protected_iter):
# --> 383       original_body(protected_iter)
#     384       after_iteration()
#     385       before_iteration()
#
# /var/folders/1y/kzwftcsj0sdf0y2rw1jkcjzm0000gn/T/tmpagq4xw7e.py in loop_body(itr)
#      25                 def loop_body(itr):
#      26                     name = itr
# ---> 27                     ag__.ld(print)(ag__.converted_call(ag__.ld(tf).reduce_mean, (((ag__.ld(style_outputs)[ag__.ld(name)] - ag__.ld(style_targets)[ag__.ld(name)]) ** 2),), None, fscope))
#      28                 name = ag__.Undefined('name')
#      29                 ag__.for_stmt(ag__.converted_call(ag__.ld(style_outputs).keys, (), None, fscope), None, loop_body, get_state, set_state, (), {'iterate_names': 'name'})
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#    1122     with ops.name_scope(None, op_name, [x, y]) as name:
#    1123       try:
# -> 1124         return func(x, y, name=name)
#    1125       except (TypeError, ValueError) as e:
#    1126         # Even if dispatching the op failed, the RHS may be a tensor aware
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in pow(x, y, name)
#     633   """
#     634   with ops.name_scope(name, "Pow", [x]) as name:
# --> 635     return gen_math_ops._pow(x, y, name=name)
#     636
#     637
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in _pow(x, y, name)
#    6667   # Add nodes to the TensorFlow graph.
#    6668   _, _, _op, _outputs = _op_def_library._apply_op_helper(
# -> 6669         "Pow", x=x, y=y, name=name)
#    6670   _result = _outputs[:]
#    6671   if _execute.must_record_gradient():
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     468               dtype=dtype,
#     469               as_ref=input_arg.is_ref,
# --> 470               preferred_dtype=default_dtype)
#     471         except TypeError as err:
#     472           if dtype is None:
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1506           "%sConversion function %r for type %s returned non-Tensor: %r" %
#    1507           (_error_prefix(name), conversion_func, base_type, ret))
# -> 1508     if dtype and not dtype.is_compatible_with(ret.dtype):
#    1509       raise RuntimeError(
#    1510           "%sConversion function %r for type %s returned incompatible "
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py in is_compatible_with(self, other)
#     188     other = as_dtype(other)
#     189     return self._type_enum in (other.as_datatype_enum,
# --> 190                                other.base_dtype.as_datatype_enum)
#     191
#     192   def __eq__(self, other):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py in base_dtype(self)
#      85   def base_dtype(self):
#      86     """Returns a non-reference `DType` based on this `DType`."""
# ---> 87     if self._is_ref_dtype:
#      88       return _INTERN_TABLE[self._type_enum - 100]
#      89     else:
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py in _is_ref_dtype(self)
#      69   __slots__ = ()
#      70
# ---> 71   @property
#      72   def _is_ref_dtype(self):
#      73     """Returns `True` if this `DType` represents a reference type."""
#
# KeyboardInterrupt:
